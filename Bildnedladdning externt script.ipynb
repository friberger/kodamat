# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
import sqlite3
import numpy as np
import random
import urllib.request
import time
import os

# %%
conn = sqlite3.connect('livs.db')  # Create db and establish connection
conn.row_factory = sqlite3.Row
curs = conn.cursor()
result = []
rows = curs.execute('select Livsmedelsnamn, Livsmedelsnummer from livs limit 2000')
for row in rows:
        result.append(row)

#rows = np.array(result)
#rows = rows[970:]
samples = random.sample(range(0, 1999), 20)
sampledFoodItems = []
#print (type(sampledFoodItems))

for index in samples:
    sampledFoodItems.append(result[index])

sampledFoodItems = np.array(sampledFoodItems)
print (samples, sampledFoodItems)

conn.close()
# Out:
# [177, 914, 1125, 1842, 1284, 1707, 210, 1926, 955, 596, 1961, 685, 54, 1099, 1354, 1348, 44, 279, 624, 1477] [['Rågbröd fullkorn osötat fibrer ca 9%' '211']
#  ['Köttbullar råa frysta' '1102']
#  ['Fiskbullar frysta' '1344']
#  ['Frukostflingor fullkorn naturell' '2245']
#  ['Prinskorv fett 24%' '1516']
#  ['Tomatsås' '2000']
#  ['Janssons frestelse' '257']
#  ['Grahamsbröd fullkorn fibrer ca 13% typ Polarkraft extrem' '3796']
#  ['Duva m skinn rå' '1155']
#  ['Havrevälling' '695']
#  ['Ägg ekologiskt stekt' '4134']
#  ['Rismjöl vitt' '810']
#  ['Hollandaisesås fryst el pulver tillagad' '64']
#  ['Kolja panerad stekt' '1315']
#  ['Sött vetebröd' '1598']
#  ['Kokosmjölk' '1590']
#  ['Räkmajonnäs el räksallad gatukök' '52']
#  ['Friséesallat' '334']
#  ['Fattiga riddare' '732']
#  ['Äppelsoppa' '1743']]

# %%
#Ca 5 sekunder för varje nedladdning, ca 3 timmar för hela db?

for keyword in sampledFoodItems:
    print (keyword[0], keyword[1])
    name="'" + keyword[0] + "'"
    number=keyword[1]
    # %run scrape-google-image-search.py $name --label $number --count 4
# Out:
# Rågbröd fullkorn osötat fibrer ca 9% 211
# Found: 0 images
# image count 36
# could not read Invalid URL 'None': No schema supplied. Perhaps you meant http://None? None
# Images downloaded:  35
# Köttbullar råa frysta 1102
# Found: 0 images
# image count 41
# could not read Invalid URL 'None': No schema supplied. Perhaps you meant http://None? None
# Images downloaded:  40
# Fiskbullar frysta 1344
# Found: 0 images
# image count 35
# could not read Invalid URL 'None': No schema supplied. Perhaps you meant http://None? None
# Images downloaded:  34
# Frukostflingor fullkorn naturell 2245
# Found: 0 images
# image count 48
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/Development/kodamat/scrape-google-image-search.py in <module>()
#     125     print("image count", len(image_urls))
#     126
# --> 127     pool = Pool(12)
#     128     results = pool.map(persist_image, values)
#     129     print("Images downloaded: ", len([r for r in results if r]))
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/context.py in Pool(self, processes, initializer, initargs, maxtasksperchild)
#     116         from .pool import Pool
#     117         return Pool(processes, initializer, initargs, maxtasksperchild,
# --> 118                     context=self.get_context())
#     119
#     120     def RawValue(self, typecode_or_type, *args):
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/pool.py in __init__(self, processes, initializer, initargs, maxtasksperchild, context)
#     172         self._processes = processes
#     173         self._pool = []
# --> 174         self._repopulate_pool()
#     175
#     176         self._worker_handler = threading.Thread(
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/pool.py in _repopulate_pool(self)
#     237             w.name = w.name.replace('Process', 'PoolWorker')
#     238             w.daemon = True
# --> 239             w.start()
#     240             util.debug('added worker')
#     241
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/process.py in start(self)
#     103                'daemonic processes are not allowed to have children'
#     104         _cleanup()
# --> 105         self._popen = self._Popen(self)
#     106         self._sentinel = self._popen.sentinel
#     107         # Avoid a refcycle if the target function holds an indirect
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/context.py in _Popen(process_obj)
#     265         def _Popen(process_obj):
#     266             from .popen_fork import Popen
# --> 267             return Popen(process_obj)
#     268
#     269     class SpawnProcess(process.BaseProcess):
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/popen_fork.py in __init__(self, process_obj)
#      18         sys.stderr.flush()
#      19         self.returncode = None
# ---> 20         self._launch(process_obj)
#      21
#      22     def duplicate_for_child(self, fd):
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/popen_fork.py in _launch(self, process_obj)
#      64     def _launch(self, process_obj):
#      65         code = 1
# ---> 66         parent_r, child_w = os.pipe()
#      67         self.pid = os.fork()
#      68         if self.pid == 0:
#
# OSError: [Errno 24] Too many open files
# Prinskorv fett 24% 1516
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/Development/kodamat/scrape-google-image-search.py in <module>()
#     119     ensure_directory(query_directory)
#     120
# --> 121     image_urls = fetch_image_urls(args.query, args.count)
#     122
#     123     values = [item for item in zip(itertools.cycle([query_directory]), image_urls)]
#
# ~/Development/kodamat/scrape-google-image-search.py in fetch_image_urls(query, images_to_download)
#      56
#      57     search_url = "https://www.google.com/search?safe=off&site=&tbm=isch&source=hp&q={q}&oq={q}&gs_l=img"
# ---> 58     browser = webdriver.Firefox()
#      59     browser.get(search_url.format(q=query))
#      60     #def scroll_to_bottom():
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/site-packages/selenium/webdriver/firefox/webdriver.py in __init__(self, firefox_profile, firefox_binary, timeout, capabilities, proxy, executable_path, firefox_options, log_path)
#     141         if capabilities.get("marionette"):
#     142             capabilities.pop("marionette")
# --> 143             self.service = Service(executable_path, log_path=log_path)
#     144             self.service.start()
#     145
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/site-packages/selenium/webdriver/firefox/service.py in __init__(self, executable_path, port, service_args, log_path, env)
#      45
#      46         service.Service.__init__(
# ---> 47             self, executable_path, port=port, log_file=log_file, env=env)
#      48         self.service_args = service_args or []
#      49
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/site-packages/selenium/webdriver/common/service.py in __init__(self, executable, port, log_file, env, start_error_message)
#      40         self.port = port
#      41         if self.port == 0:
# ---> 42             self.port = utils.free_port()
#      43
#      44         if not _HAS_NATIVE_DEVNULL and log_file == DEVNULL:
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/site-packages/selenium/webdriver/common/utils.py in free_port()
#      33     Determines a free port using sockets.
#      34     """
# ---> 35     free_socket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
#      36     free_socket.bind(('0.0.0.0', 0))
#      37     free_socket.listen(5)
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/socket.py in __init__(self, family, type, proto, fileno)
#     132         # constructor of _socket.socket converts the given argument to an
#     133         # integer automatically.
# --> 134         _socket.socket.__init__(self, family, type, proto, fileno)
#     135         self._io_refs = 0
#     136         self._closed = False
#
# OSError: [Errno 24] Too many open files
# Tomatsås 2000
# Found: 0 images
# image count 31
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/Development/kodamat/scrape-google-image-search.py in <module>()
#     125     print("image count", len(image_urls))
#     126
# --> 127     pool = Pool(12)
#     128     results = pool.map(persist_image, values)
#     129     print("Images downloaded: ", len([r for r in results if r]))
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/context.py in Pool(self, processes, initializer, initargs, maxtasksperchild)
#     116         from .pool import Pool
#     117         return Pool(processes, initializer, initargs, maxtasksperchild,
# --> 118                     context=self.get_context())
#     119
#     120     def RawValue(self, typecode_or_type, *args):
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/pool.py in __init__(self, processes, initializer, initargs, maxtasksperchild, context)
#     172         self._processes = processes
#     173         self._pool = []
# --> 174         self._repopulate_pool()
#     175
#     176         self._worker_handler = threading.Thread(
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/pool.py in _repopulate_pool(self)
#     237             w.name = w.name.replace('Process', 'PoolWorker')
#     238             w.daemon = True
# --> 239             w.start()
#     240             util.debug('added worker')
#     241
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/process.py in start(self)
#     103                'daemonic processes are not allowed to have children'
#     104         _cleanup()
# --> 105         self._popen = self._Popen(self)
#     106         self._sentinel = self._popen.sentinel
#     107         # Avoid a refcycle if the target function holds an indirect
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/context.py in _Popen(process_obj)
#     265         def _Popen(process_obj):
#     266             from .popen_fork import Popen
# --> 267             return Popen(process_obj)
#     268
#     269     class SpawnProcess(process.BaseProcess):
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/popen_fork.py in __init__(self, process_obj)
#      18         sys.stderr.flush()
#      19         self.returncode = None
# ---> 20         self._launch(process_obj)
#      21
#      22     def duplicate_for_child(self, fd):
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/popen_fork.py in _launch(self, process_obj)
#      64     def _launch(self, process_obj):
#      65         code = 1
# ---> 66         parent_r, child_w = os.pipe()
#      67         self.pid = os.fork()
#      68         if self.pid == 0:
#
# OSError: [Errno 24] Too many open files
# Janssons frestelse 257
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/Development/kodamat/scrape-google-image-search.py in <module>()
#     119     ensure_directory(query_directory)
#     120
# --> 121     image_urls = fetch_image_urls(args.query, args.count)
#     122
#     123     values = [item for item in zip(itertools.cycle([query_directory]), image_urls)]
#
# ~/Development/kodamat/scrape-google-image-search.py in fetch_image_urls(query, images_to_download)
#      56
#      57     search_url = "https://www.google.com/search?safe=off&site=&tbm=isch&source=hp&q={q}&oq={q}&gs_l=img"
# ---> 58     browser = webdriver.Firefox()
#      59     browser.get(search_url.format(q=query))
#      60     #def scroll_to_bottom():
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/site-packages/selenium/webdriver/firefox/webdriver.py in __init__(self, firefox_profile, firefox_binary, timeout, capabilities, proxy, executable_path, firefox_options, log_path)
#     142             capabilities.pop("marionette")
#     143             self.service = Service(executable_path, log_path=log_path)
# --> 144             self.service.start()
#     145
#     146             capabilities.update(firefox_options.to_capabilities())
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/site-packages/selenium/webdriver/common/service.py in start(self)
#      72             self.process = subprocess.Popen(cmd, env=self.env,
#      73                                             close_fds=platform.system() != 'Windows',
# ---> 74                                             stdout=self.log_file, stderr=self.log_file)
#      75         except TypeError:
#      76             raise
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds)
#     674                                 c2pread, c2pwrite,
#     675                                 errread, errwrite,
# --> 676                                 restore_signals, start_new_session)
#     677         except:
#     678             # Cleanup if the child failed starting.
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1185             # Data format: "exception name:hex errno:description"
#    1186             # Pickle is not used; it is complex and involves memory allocation.
# -> 1187             errpipe_read, errpipe_write = os.pipe()
#    1188             # errpipe_write must not be in the standard io 0, 1, or 2 fd range.
#    1189             low_fds_to_close = []
#
# OSError: [Errno 24] Too many open files
# Grahamsbröd fullkorn fibrer ca 13% typ Polarkraft extrem 3796
# Found: 0 images
# image count 36
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/Development/kodamat/scrape-google-image-search.py in <module>()
#     125     print("image count", len(image_urls))
#     126
# --> 127     pool = Pool(12)
#     128     results = pool.map(persist_image, values)
#     129     print("Images downloaded: ", len([r for r in results if r]))
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/context.py in Pool(self, processes, initializer, initargs, maxtasksperchild)
#     116         from .pool import Pool
#     117         return Pool(processes, initializer, initargs, maxtasksperchild,
# --> 118                     context=self.get_context())
#     119
#     120     def RawValue(self, typecode_or_type, *args):
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/pool.py in __init__(self, processes, initializer, initargs, maxtasksperchild, context)
#     172         self._processes = processes
#     173         self._pool = []
# --> 174         self._repopulate_pool()
#     175
#     176         self._worker_handler = threading.Thread(
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/pool.py in _repopulate_pool(self)
#     237             w.name = w.name.replace('Process', 'PoolWorker')
#     238             w.daemon = True
# --> 239             w.start()
#     240             util.debug('added worker')
#     241
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/process.py in start(self)
#     103                'daemonic processes are not allowed to have children'
#     104         _cleanup()
# --> 105         self._popen = self._Popen(self)
#     106         self._sentinel = self._popen.sentinel
#     107         # Avoid a refcycle if the target function holds an indirect
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/context.py in _Popen(process_obj)
#     265         def _Popen(process_obj):
#     266             from .popen_fork import Popen
# --> 267             return Popen(process_obj)
#     268
#     269     class SpawnProcess(process.BaseProcess):
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/popen_fork.py in __init__(self, process_obj)
#      18         sys.stderr.flush()
#      19         self.returncode = None
# ---> 20         self._launch(process_obj)
#      21
#      22     def duplicate_for_child(self, fd):
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/popen_fork.py in _launch(self, process_obj)
#      64     def _launch(self, process_obj):
#      65         code = 1
# ---> 66         parent_r, child_w = os.pipe()
#      67         self.pid = os.fork()
#      68         if self.pid == 0:
#
# OSError: [Errno 24] Too many open files
# Duva m skinn rå 1155
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/Development/kodamat/scrape-google-image-search.py in <module>()
#     119     ensure_directory(query_directory)
#     120
# --> 121     image_urls = fetch_image_urls(args.query, args.count)
#     122
#     123     values = [item for item in zip(itertools.cycle([query_directory]), image_urls)]
#
# ~/Development/kodamat/scrape-google-image-search.py in fetch_image_urls(query, images_to_download)
#      56
#      57     search_url = "https://www.google.com/search?safe=off&site=&tbm=isch&source=hp&q={q}&oq={q}&gs_l=img"
# ---> 58     browser = webdriver.Firefox()
#      59     browser.get(search_url.format(q=query))
#      60     #def scroll_to_bottom():
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/site-packages/selenium/webdriver/firefox/webdriver.py in __init__(self, firefox_profile, firefox_binary, timeout, capabilities, proxy, executable_path, firefox_options, log_path)
#     142             capabilities.pop("marionette")
#     143             self.service = Service(executable_path, log_path=log_path)
# --> 144             self.service.start()
#     145
#     146             capabilities.update(firefox_options.to_capabilities())
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/site-packages/selenium/webdriver/common/service.py in start(self)
#      72             self.process = subprocess.Popen(cmd, env=self.env,
#      73                                             close_fds=platform.system() != 'Windows',
# ---> 74                                             stdout=self.log_file, stderr=self.log_file)
#      75         except TypeError:
#      76             raise
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds)
#     674                                 c2pread, c2pwrite,
#     675                                 errread, errwrite,
# --> 676                                 restore_signals, start_new_session)
#     677         except:
#     678             # Cleanup if the child failed starting.
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1185             # Data format: "exception name:hex errno:description"
#    1186             # Pickle is not used; it is complex and involves memory allocation.
# -> 1187             errpipe_read, errpipe_write = os.pipe()
#    1188             # errpipe_write must not be in the standard io 0, 1, or 2 fd range.
#    1189             low_fds_to_close = []
#
# OSError: [Errno 24] Too many open files
# Havrevälling 695
# Found: 0 images
# image count 48
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/Development/kodamat/scrape-google-image-search.py in <module>()
#     125     print("image count", len(image_urls))
#     126
# --> 127     pool = Pool(12)
#     128     results = pool.map(persist_image, values)
#     129     print("Images downloaded: ", len([r for r in results if r]))
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/context.py in Pool(self, processes, initializer, initargs, maxtasksperchild)
#     116         from .pool import Pool
#     117         return Pool(processes, initializer, initargs, maxtasksperchild,
# --> 118                     context=self.get_context())
#     119
#     120     def RawValue(self, typecode_or_type, *args):
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/pool.py in __init__(self, processes, initializer, initargs, maxtasksperchild, context)
#     172         self._processes = processes
#     173         self._pool = []
# --> 174         self._repopulate_pool()
#     175
#     176         self._worker_handler = threading.Thread(
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/pool.py in _repopulate_pool(self)
#     237             w.name = w.name.replace('Process', 'PoolWorker')
#     238             w.daemon = True
# --> 239             w.start()
#     240             util.debug('added worker')
#     241
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/process.py in start(self)
#     103                'daemonic processes are not allowed to have children'
#     104         _cleanup()
# --> 105         self._popen = self._Popen(self)
#     106         self._sentinel = self._popen.sentinel
#     107         # Avoid a refcycle if the target function holds an indirect
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/context.py in _Popen(process_obj)
#     265         def _Popen(process_obj):
#     266             from .popen_fork import Popen
# --> 267             return Popen(process_obj)
#     268
#     269     class SpawnProcess(process.BaseProcess):
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/popen_fork.py in __init__(self, process_obj)
#      18         sys.stderr.flush()
#      19         self.returncode = None
# ---> 20         self._launch(process_obj)
#      21
#      22     def duplicate_for_child(self, fd):
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/popen_fork.py in _launch(self, process_obj)
#      64     def _launch(self, process_obj):
#      65         code = 1
# ---> 66         parent_r, child_w = os.pipe()
#      67         self.pid = os.fork()
#      68         if self.pid == 0:
#
# OSError: [Errno 24] Too many open files
# Ägg ekologiskt stekt 4134
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/Development/kodamat/scrape-google-image-search.py in <module>()
#     119     ensure_directory(query_directory)
#     120
# --> 121     image_urls = fetch_image_urls(args.query, args.count)
#     122
#     123     values = [item for item in zip(itertools.cycle([query_directory]), image_urls)]
#
# ~/Development/kodamat/scrape-google-image-search.py in fetch_image_urls(query, images_to_download)
#      56
#      57     search_url = "https://www.google.com/search?safe=off&site=&tbm=isch&source=hp&q={q}&oq={q}&gs_l=img"
# ---> 58     browser = webdriver.Firefox()
#      59     browser.get(search_url.format(q=query))
#      60     #def scroll_to_bottom():
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/site-packages/selenium/webdriver/firefox/webdriver.py in __init__(self, firefox_profile, firefox_binary, timeout, capabilities, proxy, executable_path, firefox_options, log_path)
#     142             capabilities.pop("marionette")
#     143             self.service = Service(executable_path, log_path=log_path)
# --> 144             self.service.start()
#     145
#     146             capabilities.update(firefox_options.to_capabilities())
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/site-packages/selenium/webdriver/common/service.py in start(self)
#      72             self.process = subprocess.Popen(cmd, env=self.env,
#      73                                             close_fds=platform.system() != 'Windows',
# ---> 74                                             stdout=self.log_file, stderr=self.log_file)
#      75         except TypeError:
#      76             raise
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds)
#     674                                 c2pread, c2pwrite,
#     675                                 errread, errwrite,
# --> 676                                 restore_signals, start_new_session)
#     677         except:
#     678             # Cleanup if the child failed starting.
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1185             # Data format: "exception name:hex errno:description"
#    1186             # Pickle is not used; it is complex and involves memory allocation.
# -> 1187             errpipe_read, errpipe_write = os.pipe()
#    1188             # errpipe_write must not be in the standard io 0, 1, or 2 fd range.
#    1189             low_fds_to_close = []
#
# OSError: [Errno 24] Too many open files
# Rismjöl vitt 810
# Found: 0 images
# image count 41
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/Development/kodamat/scrape-google-image-search.py in <module>()
#     125     print("image count", len(image_urls))
#     126
# --> 127     pool = Pool(12)
#     128     results = pool.map(persist_image, values)
#     129     print("Images downloaded: ", len([r for r in results if r]))
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/context.py in Pool(self, processes, initializer, initargs, maxtasksperchild)
#     116         from .pool import Pool
#     117         return Pool(processes, initializer, initargs, maxtasksperchild,
# --> 118                     context=self.get_context())
#     119
#     120     def RawValue(self, typecode_or_type, *args):
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/pool.py in __init__(self, processes, initializer, initargs, maxtasksperchild, context)
#     172         self._processes = processes
#     173         self._pool = []
# --> 174         self._repopulate_pool()
#     175
#     176         self._worker_handler = threading.Thread(
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/pool.py in _repopulate_pool(self)
#     237             w.name = w.name.replace('Process', 'PoolWorker')
#     238             w.daemon = True
# --> 239             w.start()
#     240             util.debug('added worker')
#     241
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/process.py in start(self)
#     103                'daemonic processes are not allowed to have children'
#     104         _cleanup()
# --> 105         self._popen = self._Popen(self)
#     106         self._sentinel = self._popen.sentinel
#     107         # Avoid a refcycle if the target function holds an indirect
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/context.py in _Popen(process_obj)
#     265         def _Popen(process_obj):
#     266             from .popen_fork import Popen
# --> 267             return Popen(process_obj)
#     268
#     269     class SpawnProcess(process.BaseProcess):
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/popen_fork.py in __init__(self, process_obj)
#      18         sys.stderr.flush()
#      19         self.returncode = None
# ---> 20         self._launch(process_obj)
#      21
#      22     def duplicate_for_child(self, fd):
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/popen_fork.py in _launch(self, process_obj)
#      64     def _launch(self, process_obj):
#      65         code = 1
# ---> 66         parent_r, child_w = os.pipe()
#      67         self.pid = os.fork()
#      68         if self.pid == 0:
#
# OSError: [Errno 24] Too many open files
# Hollandaisesås fryst el pulver tillagad 64
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/Development/kodamat/scrape-google-image-search.py in <module>()
#     119     ensure_directory(query_directory)
#     120
# --> 121     image_urls = fetch_image_urls(args.query, args.count)
#     122
#     123     values = [item for item in zip(itertools.cycle([query_directory]), image_urls)]
#
# ~/Development/kodamat/scrape-google-image-search.py in fetch_image_urls(query, images_to_download)
#      56
#      57     search_url = "https://www.google.com/search?safe=off&site=&tbm=isch&source=hp&q={q}&oq={q}&gs_l=img"
# ---> 58     browser = webdriver.Firefox()
#      59     browser.get(search_url.format(q=query))
#      60     #def scroll_to_bottom():
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/site-packages/selenium/webdriver/firefox/webdriver.py in __init__(self, firefox_profile, firefox_binary, timeout, capabilities, proxy, executable_path, firefox_options, log_path)
#     142             capabilities.pop("marionette")
#     143             self.service = Service(executable_path, log_path=log_path)
# --> 144             self.service.start()
#     145
#     146             capabilities.update(firefox_options.to_capabilities())
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/site-packages/selenium/webdriver/common/service.py in start(self)
#      72             self.process = subprocess.Popen(cmd, env=self.env,
#      73                                             close_fds=platform.system() != 'Windows',
# ---> 74                                             stdout=self.log_file, stderr=self.log_file)
#      75         except TypeError:
#      76             raise
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds)
#     674                                 c2pread, c2pwrite,
#     675                                 errread, errwrite,
# --> 676                                 restore_signals, start_new_session)
#     677         except:
#     678             # Cleanup if the child failed starting.
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1185             # Data format: "exception name:hex errno:description"
#    1186             # Pickle is not used; it is complex and involves memory allocation.
# -> 1187             errpipe_read, errpipe_write = os.pipe()
#    1188             # errpipe_write must not be in the standard io 0, 1, or 2 fd range.
#    1189             low_fds_to_close = []
#
# OSError: [Errno 24] Too many open files
# Kolja panerad stekt 1315
# Found: 0 images
# image count 38
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/Development/kodamat/scrape-google-image-search.py in <module>()
#     125     print("image count", len(image_urls))
#     126
# --> 127     pool = Pool(12)
#     128     results = pool.map(persist_image, values)
#     129     print("Images downloaded: ", len([r for r in results if r]))
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/context.py in Pool(self, processes, initializer, initargs, maxtasksperchild)
#     116         from .pool import Pool
#     117         return Pool(processes, initializer, initargs, maxtasksperchild,
# --> 118                     context=self.get_context())
#     119
#     120     def RawValue(self, typecode_or_type, *args):
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/pool.py in __init__(self, processes, initializer, initargs, maxtasksperchild, context)
#     172         self._processes = processes
#     173         self._pool = []
# --> 174         self._repopulate_pool()
#     175
#     176         self._worker_handler = threading.Thread(
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/pool.py in _repopulate_pool(self)
#     237             w.name = w.name.replace('Process', 'PoolWorker')
#     238             w.daemon = True
# --> 239             w.start()
#     240             util.debug('added worker')
#     241
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/process.py in start(self)
#     103                'daemonic processes are not allowed to have children'
#     104         _cleanup()
# --> 105         self._popen = self._Popen(self)
#     106         self._sentinel = self._popen.sentinel
#     107         # Avoid a refcycle if the target function holds an indirect
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/context.py in _Popen(process_obj)
#     265         def _Popen(process_obj):
#     266             from .popen_fork import Popen
# --> 267             return Popen(process_obj)
#     268
#     269     class SpawnProcess(process.BaseProcess):
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/popen_fork.py in __init__(self, process_obj)
#      18         sys.stderr.flush()
#      19         self.returncode = None
# ---> 20         self._launch(process_obj)
#      21
#      22     def duplicate_for_child(self, fd):
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/popen_fork.py in _launch(self, process_obj)
#      64     def _launch(self, process_obj):
#      65         code = 1
# ---> 66         parent_r, child_w = os.pipe()
#      67         self.pid = os.fork()
#      68         if self.pid == 0:
#
# OSError: [Errno 24] Too many open files
# Sött vetebröd 1598
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/Development/kodamat/scrape-google-image-search.py in <module>()
#     119     ensure_directory(query_directory)
#     120
# --> 121     image_urls = fetch_image_urls(args.query, args.count)
#     122
#     123     values = [item for item in zip(itertools.cycle([query_directory]), image_urls)]
#
# ~/Development/kodamat/scrape-google-image-search.py in fetch_image_urls(query, images_to_download)
#      56
#      57     search_url = "https://www.google.com/search?safe=off&site=&tbm=isch&source=hp&q={q}&oq={q}&gs_l=img"
# ---> 58     browser = webdriver.Firefox()
#      59     browser.get(search_url.format(q=query))
#      60     #def scroll_to_bottom():
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/site-packages/selenium/webdriver/firefox/webdriver.py in __init__(self, firefox_profile, firefox_binary, timeout, capabilities, proxy, executable_path, firefox_options, log_path)
#     142             capabilities.pop("marionette")
#     143             self.service = Service(executable_path, log_path=log_path)
# --> 144             self.service.start()
#     145
#     146             capabilities.update(firefox_options.to_capabilities())
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/site-packages/selenium/webdriver/common/service.py in start(self)
#      72             self.process = subprocess.Popen(cmd, env=self.env,
#      73                                             close_fds=platform.system() != 'Windows',
# ---> 74                                             stdout=self.log_file, stderr=self.log_file)
#      75         except TypeError:
#      76             raise
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds)
#     674                                 c2pread, c2pwrite,
#     675                                 errread, errwrite,
# --> 676                                 restore_signals, start_new_session)
#     677         except:
#     678             # Cleanup if the child failed starting.
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1185             # Data format: "exception name:hex errno:description"
#    1186             # Pickle is not used; it is complex and involves memory allocation.
# -> 1187             errpipe_read, errpipe_write = os.pipe()
#    1188             # errpipe_write must not be in the standard io 0, 1, or 2 fd range.
#    1189             low_fds_to_close = []
#
# OSError: [Errno 24] Too many open files
# Kokosmjölk 1590
# Found: 0 images
# image count 39
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/Development/kodamat/scrape-google-image-search.py in <module>()
#     125     print("image count", len(image_urls))
#     126
# --> 127     pool = Pool(12)
#     128     results = pool.map(persist_image, values)
#     129     print("Images downloaded: ", len([r for r in results if r]))
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/context.py in Pool(self, processes, initializer, initargs, maxtasksperchild)
#     116         from .pool import Pool
#     117         return Pool(processes, initializer, initargs, maxtasksperchild,
# --> 118                     context=self.get_context())
#     119
#     120     def RawValue(self, typecode_or_type, *args):
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/pool.py in __init__(self, processes, initializer, initargs, maxtasksperchild, context)
#     172         self._processes = processes
#     173         self._pool = []
# --> 174         self._repopulate_pool()
#     175
#     176         self._worker_handler = threading.Thread(
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/pool.py in _repopulate_pool(self)
#     237             w.name = w.name.replace('Process', 'PoolWorker')
#     238             w.daemon = True
# --> 239             w.start()
#     240             util.debug('added worker')
#     241
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/process.py in start(self)
#     103                'daemonic processes are not allowed to have children'
#     104         _cleanup()
# --> 105         self._popen = self._Popen(self)
#     106         self._sentinel = self._popen.sentinel
#     107         # Avoid a refcycle if the target function holds an indirect
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/context.py in _Popen(process_obj)
#     265         def _Popen(process_obj):
#     266             from .popen_fork import Popen
# --> 267             return Popen(process_obj)
#     268
#     269     class SpawnProcess(process.BaseProcess):
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/popen_fork.py in __init__(self, process_obj)
#      18         sys.stderr.flush()
#      19         self.returncode = None
# ---> 20         self._launch(process_obj)
#      21
#      22     def duplicate_for_child(self, fd):
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/popen_fork.py in _launch(self, process_obj)
#      64     def _launch(self, process_obj):
#      65         code = 1
# ---> 66         parent_r, child_w = os.pipe()
#      67         self.pid = os.fork()
#      68         if self.pid == 0:
#
# OSError: [Errno 24] Too many open files
# Räkmajonnäs el räksallad gatukök 52
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/Development/kodamat/scrape-google-image-search.py in <module>()
#     119     ensure_directory(query_directory)
#     120
# --> 121     image_urls = fetch_image_urls(args.query, args.count)
#     122
#     123     values = [item for item in zip(itertools.cycle([query_directory]), image_urls)]
#
# ~/Development/kodamat/scrape-google-image-search.py in fetch_image_urls(query, images_to_download)
#      56
#      57     search_url = "https://www.google.com/search?safe=off&site=&tbm=isch&source=hp&q={q}&oq={q}&gs_l=img"
# ---> 58     browser = webdriver.Firefox()
#      59     browser.get(search_url.format(q=query))
#      60     #def scroll_to_bottom():
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/site-packages/selenium/webdriver/firefox/webdriver.py in __init__(self, firefox_profile, firefox_binary, timeout, capabilities, proxy, executable_path, firefox_options, log_path)
#     142             capabilities.pop("marionette")
#     143             self.service = Service(executable_path, log_path=log_path)
# --> 144             self.service.start()
#     145
#     146             capabilities.update(firefox_options.to_capabilities())
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/site-packages/selenium/webdriver/common/service.py in start(self)
#      72             self.process = subprocess.Popen(cmd, env=self.env,
#      73                                             close_fds=platform.system() != 'Windows',
# ---> 74                                             stdout=self.log_file, stderr=self.log_file)
#      75         except TypeError:
#      76             raise
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds)
#     674                                 c2pread, c2pwrite,
#     675                                 errread, errwrite,
# --> 676                                 restore_signals, start_new_session)
#     677         except:
#     678             # Cleanup if the child failed starting.
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1185             # Data format: "exception name:hex errno:description"
#    1186             # Pickle is not used; it is complex and involves memory allocation.
# -> 1187             errpipe_read, errpipe_write = os.pipe()
#    1188             # errpipe_write must not be in the standard io 0, 1, or 2 fd range.
#    1189             low_fds_to_close = []
#
# OSError: [Errno 24] Too many open files
# Friséesallat 334
# Found: 0 images
# image count 44
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/Development/kodamat/scrape-google-image-search.py in <module>()
#     125     print("image count", len(image_urls))
#     126
# --> 127     pool = Pool(12)
#     128     results = pool.map(persist_image, values)
#     129     print("Images downloaded: ", len([r for r in results if r]))
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/context.py in Pool(self, processes, initializer, initargs, maxtasksperchild)
#     116         from .pool import Pool
#     117         return Pool(processes, initializer, initargs, maxtasksperchild,
# --> 118                     context=self.get_context())
#     119
#     120     def RawValue(self, typecode_or_type, *args):
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/pool.py in __init__(self, processes, initializer, initargs, maxtasksperchild, context)
#     172         self._processes = processes
#     173         self._pool = []
# --> 174         self._repopulate_pool()
#     175
#     176         self._worker_handler = threading.Thread(
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/pool.py in _repopulate_pool(self)
#     237             w.name = w.name.replace('Process', 'PoolWorker')
#     238             w.daemon = True
# --> 239             w.start()
#     240             util.debug('added worker')
#     241
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/process.py in start(self)
#     103                'daemonic processes are not allowed to have children'
#     104         _cleanup()
# --> 105         self._popen = self._Popen(self)
#     106         self._sentinel = self._popen.sentinel
#     107         # Avoid a refcycle if the target function holds an indirect
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/context.py in _Popen(process_obj)
#     265         def _Popen(process_obj):
#     266             from .popen_fork import Popen
# --> 267             return Popen(process_obj)
#     268
#     269     class SpawnProcess(process.BaseProcess):
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/popen_fork.py in __init__(self, process_obj)
#      18         sys.stderr.flush()
#      19         self.returncode = None
# ---> 20         self._launch(process_obj)
#      21
#      22     def duplicate_for_child(self, fd):
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/popen_fork.py in _launch(self, process_obj)
#      64     def _launch(self, process_obj):
#      65         code = 1
# ---> 66         parent_r, child_w = os.pipe()
#      67         self.pid = os.fork()
#      68         if self.pid == 0:
#
# OSError: [Errno 24] Too many open files
# Fattiga riddare 732
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/Development/kodamat/scrape-google-image-search.py in <module>()
#     119     ensure_directory(query_directory)
#     120
# --> 121     image_urls = fetch_image_urls(args.query, args.count)
#     122
#     123     values = [item for item in zip(itertools.cycle([query_directory]), image_urls)]
#
# ~/Development/kodamat/scrape-google-image-search.py in fetch_image_urls(query, images_to_download)
#      56
#      57     search_url = "https://www.google.com/search?safe=off&site=&tbm=isch&source=hp&q={q}&oq={q}&gs_l=img"
# ---> 58     browser = webdriver.Firefox()
#      59     browser.get(search_url.format(q=query))
#      60     #def scroll_to_bottom():
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/site-packages/selenium/webdriver/firefox/webdriver.py in __init__(self, firefox_profile, firefox_binary, timeout, capabilities, proxy, executable_path, firefox_options, log_path)
#     142             capabilities.pop("marionette")
#     143             self.service = Service(executable_path, log_path=log_path)
# --> 144             self.service.start()
#     145
#     146             capabilities.update(firefox_options.to_capabilities())
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/site-packages/selenium/webdriver/common/service.py in start(self)
#      72             self.process = subprocess.Popen(cmd, env=self.env,
#      73                                             close_fds=platform.system() != 'Windows',
# ---> 74                                             stdout=self.log_file, stderr=self.log_file)
#      75         except TypeError:
#      76             raise
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds)
#     674                                 c2pread, c2pwrite,
#     675                                 errread, errwrite,
# --> 676                                 restore_signals, start_new_session)
#     677         except:
#     678             # Cleanup if the child failed starting.
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1185             # Data format: "exception name:hex errno:description"
#    1186             # Pickle is not used; it is complex and involves memory allocation.
# -> 1187             errpipe_read, errpipe_write = os.pipe()
#    1188             # errpipe_write must not be in the standard io 0, 1, or 2 fd range.
#    1189             low_fds_to_close = []
#
# OSError: [Errno 24] Too many open files
# Äppelsoppa 1743
# Found: 0 images
# image count 39
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/Development/kodamat/scrape-google-image-search.py in <module>()
#     125     print("image count", len(image_urls))
#     126
# --> 127     pool = Pool(12)
#     128     results = pool.map(persist_image, values)
#     129     print("Images downloaded: ", len([r for r in results if r]))
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/context.py in Pool(self, processes, initializer, initargs, maxtasksperchild)
#     116         from .pool import Pool
#     117         return Pool(processes, initializer, initargs, maxtasksperchild,
# --> 118                     context=self.get_context())
#     119
#     120     def RawValue(self, typecode_or_type, *args):
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/pool.py in __init__(self, processes, initializer, initargs, maxtasksperchild, context)
#     172         self._processes = processes
#     173         self._pool = []
# --> 174         self._repopulate_pool()
#     175
#     176         self._worker_handler = threading.Thread(
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/pool.py in _repopulate_pool(self)
#     237             w.name = w.name.replace('Process', 'PoolWorker')
#     238             w.daemon = True
# --> 239             w.start()
#     240             util.debug('added worker')
#     241
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/process.py in start(self)
#     103                'daemonic processes are not allowed to have children'
#     104         _cleanup()
# --> 105         self._popen = self._Popen(self)
#     106         self._sentinel = self._popen.sentinel
#     107         # Avoid a refcycle if the target function holds an indirect
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/context.py in _Popen(process_obj)
#     265         def _Popen(process_obj):
#     266             from .popen_fork import Popen
# --> 267             return Popen(process_obj)
#     268
#     269     class SpawnProcess(process.BaseProcess):
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/popen_fork.py in __init__(self, process_obj)
#      18         sys.stderr.flush()
#      19         self.returncode = None
# ---> 20         self._launch(process_obj)
#      21
#      22     def duplicate_for_child(self, fd):
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/popen_fork.py in _launch(self, process_obj)
#      64     def _launch(self, process_obj):
#      65         code = 1
# ---> 66         parent_r, child_w = os.pipe()
#      67         self.pid = os.fork()
#      68         if self.pid == 0:
#
# OSError: [Errno 24] Too many open files
