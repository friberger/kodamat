# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
import sqlite3
import numpy as np
import random
import urllib.request
import time
import os

# %%
conn = sqlite3.connect('livs.db')  # Create db and establish connection
conn.row_factory = sqlite3.Row
curs = conn.cursor()
result = []
rows = curs.execute('select Livsmedelsnamn, Livsmedelsnummer from livs limit 2000')
for row in rows:
        result.append(row)

#rows = np.array(result)
#rows = rows[970:]
samples = random.sample(range(0, 1999), 10)
sampledFoodItems = []
#print (type(sampledFoodItems))

for index in samples:
    sampledFoodItems.append(result[index])

sampledFoodItems = np.array(sampledFoodItems)
print (samples, sampledFoodItems)

conn.close()
# Out:
# [723, 1585, 94, 1803, 1469, 821, 1276, 376, 1481, 14] [['Lasagne portionsbit typ Billys' '869']
#  ['Polkagrisar' '1869']
#  ['Färskost fett 35% Boursin' '104']
#  ['Currysås Lätt Crème Fraiche' '2173']
#  ['Gräddfils- o crème fraichesås' '1728']
#  ['Gris fläsk kotlett fett bortskuret rå' '982']
#  ['Grillkorv fett 15%' '1508']
#  ['Blomkål gratinerad' '433']
#  ['Saftsoppa' '1747']
#  ['Lättmargarin fett 40% berikad typ Lätt & lagom' '20']]

# %%
#Ca 5 sekunder för varje nedladdning, ca 3 timmar för hela db?

for keyword in sampledFoodItems:
    print (keyword[0], keyword[1])
    name="'" + keyword[0] + "'"
    number=keyword[1]
    # %run scrape-google-image-search.py $name --label $number --count 4
# Out:
# Lasagne portionsbit typ Billys 869
# Found: 0 images
# image count 1
# Images downloaded:  1
# Polkagrisar 1869
# Found: 0 images
# image count 1
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/Development/kodamat/scrape-google-image-search.py in <module>()
#     125     print("image count", len(image_urls))
#     126
# --> 127     pool = Pool(12)
#     128     results = pool.map(persist_image, values)
#     129     print("Images downloaded: ", len([r for r in results if r]))
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/context.py in Pool(self, processes, initializer, initargs, maxtasksperchild)
#     116         from .pool import Pool
#     117         return Pool(processes, initializer, initargs, maxtasksperchild,
# --> 118                     context=self.get_context())
#     119
#     120     def RawValue(self, typecode_or_type, *args):
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/pool.py in __init__(self, processes, initializer, initargs, maxtasksperchild, context)
#     154                  maxtasksperchild=None, context=None):
#     155         self._ctx = context or get_context()
# --> 156         self._setup_queues()
#     157         self._taskqueue = queue.Queue()
#     158         self._cache = {}
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/pool.py in _setup_queues(self)
#     248     def _setup_queues(self):
#     249         self._inqueue = self._ctx.SimpleQueue()
# --> 250         self._outqueue = self._ctx.SimpleQueue()
#     251         self._quick_put = self._inqueue._writer.send
#     252         self._quick_get = self._outqueue._reader.recv
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/context.py in SimpleQueue(self)
#     109         '''Returns a queue object'''
#     110         from .queues import SimpleQueue
# --> 111         return SimpleQueue(ctx=self.get_context())
#     112
#     113     def Pool(self, processes=None, initializer=None, initargs=(),
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/queues.py in __init__(self, ctx)
#     313     def __init__(self, *, ctx):
#     314         self._reader, self._writer = connection.Pipe(duplex=False)
# --> 315         self._rlock = ctx.Lock()
#     316         self._poll = self._reader.poll
#     317         if sys.platform == 'win32':
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/context.py in Lock(self)
#      64         '''Returns a non-recursive lock object'''
#      65         from .synchronize import Lock
# ---> 66         return Lock(ctx=self.get_context())
#      67
#      68     def RLock(self):
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/synchronize.py in __init__(self, ctx)
#     161
#     162     def __init__(self, *, ctx):
# --> 163         SemLock.__init__(self, SEMAPHORE, 1, 1, ctx=ctx)
#     164
#     165     def __repr__(self):
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/synchronize.py in __init__(self, kind, value, maxvalue, ctx)
#      58                 sl = self._semlock = _multiprocessing.SemLock(
#      59                     kind, value, maxvalue, self._make_name(),
# ---> 60                     unlink_now)
#      61             except FileExistsError:
#      62                 pass
#
# OSError: [Errno 24] Too many open files
# Färskost fett 35% Boursin 104
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/Development/kodamat/scrape-google-image-search.py in <module>()
#     119     ensure_directory(query_directory)
#     120
# --> 121     image_urls = fetch_image_urls(args.query, args.count)
#     122
#     123     values = [item for item in zip(itertools.cycle([query_directory]), image_urls)]
#
# ~/Development/kodamat/scrape-google-image-search.py in fetch_image_urls(query, images_to_download)
#      56
#      57     search_url = "https://www.google.com/search?safe=off&site=&tbm=isch&source=hp&q={q}&oq={q}&gs_l=img"
# ---> 58     browser = webdriver.Firefox()
#      59     browser.get(search_url.format(q=query))
#      60     #def scroll_to_bottom():
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/site-packages/selenium/webdriver/firefox/webdriver.py in __init__(self, firefox_profile, firefox_binary, timeout, capabilities, proxy, executable_path, firefox_options, log_path)
#     141         if capabilities.get("marionette"):
#     142             capabilities.pop("marionette")
# --> 143             self.service = Service(executable_path, log_path=log_path)
#     144             self.service.start()
#     145
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/site-packages/selenium/webdriver/firefox/service.py in __init__(self, executable_path, port, service_args, log_path, env)
#      42
#      43         """
# ---> 44         log_file = open(log_path, "a+") if log_path is not None and log_path != "" else None
#      45
#      46         service.Service.__init__(
#
# OSError: [Errno 24] Too many open files: 'geckodriver.log'
# Currysås Lätt Crème Fraiche 2173
# Found: 0 images
# image count 1
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/Development/kodamat/scrape-google-image-search.py in <module>()
#     125     print("image count", len(image_urls))
#     126
# --> 127     pool = Pool(12)
#     128     results = pool.map(persist_image, values)
#     129     print("Images downloaded: ", len([r for r in results if r]))
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/context.py in Pool(self, processes, initializer, initargs, maxtasksperchild)
#     116         from .pool import Pool
#     117         return Pool(processes, initializer, initargs, maxtasksperchild,
# --> 118                     context=self.get_context())
#     119
#     120     def RawValue(self, typecode_or_type, *args):
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/pool.py in __init__(self, processes, initializer, initargs, maxtasksperchild, context)
#     154                  maxtasksperchild=None, context=None):
#     155         self._ctx = context or get_context()
# --> 156         self._setup_queues()
#     157         self._taskqueue = queue.Queue()
#     158         self._cache = {}
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/pool.py in _setup_queues(self)
#     248     def _setup_queues(self):
#     249         self._inqueue = self._ctx.SimpleQueue()
# --> 250         self._outqueue = self._ctx.SimpleQueue()
#     251         self._quick_put = self._inqueue._writer.send
#     252         self._quick_get = self._outqueue._reader.recv
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/context.py in SimpleQueue(self)
#     109         '''Returns a queue object'''
#     110         from .queues import SimpleQueue
# --> 111         return SimpleQueue(ctx=self.get_context())
#     112
#     113     def Pool(self, processes=None, initializer=None, initargs=(),
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/queues.py in __init__(self, ctx)
#     313     def __init__(self, *, ctx):
#     314         self._reader, self._writer = connection.Pipe(duplex=False)
# --> 315         self._rlock = ctx.Lock()
#     316         self._poll = self._reader.poll
#     317         if sys.platform == 'win32':
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/context.py in Lock(self)
#      64         '''Returns a non-recursive lock object'''
#      65         from .synchronize import Lock
# ---> 66         return Lock(ctx=self.get_context())
#      67
#      68     def RLock(self):
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/synchronize.py in __init__(self, ctx)
#     161
#     162     def __init__(self, *, ctx):
# --> 163         SemLock.__init__(self, SEMAPHORE, 1, 1, ctx=ctx)
#     164
#     165     def __repr__(self):
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/synchronize.py in __init__(self, kind, value, maxvalue, ctx)
#      58                 sl = self._semlock = _multiprocessing.SemLock(
#      59                     kind, value, maxvalue, self._make_name(),
# ---> 60                     unlink_now)
#      61             except FileExistsError:
#      62                 pass
#
# OSError: [Errno 24] Too many open files
# Gräddfils- o crème fraichesås 1728
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/Development/kodamat/scrape-google-image-search.py in <module>()
#     119     ensure_directory(query_directory)
#     120
# --> 121     image_urls = fetch_image_urls(args.query, args.count)
#     122
#     123     values = [item for item in zip(itertools.cycle([query_directory]), image_urls)]
#
# ~/Development/kodamat/scrape-google-image-search.py in fetch_image_urls(query, images_to_download)
#      56
#      57     search_url = "https://www.google.com/search?safe=off&site=&tbm=isch&source=hp&q={q}&oq={q}&gs_l=img"
# ---> 58     browser = webdriver.Firefox()
#      59     browser.get(search_url.format(q=query))
#      60     #def scroll_to_bottom():
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/site-packages/selenium/webdriver/firefox/webdriver.py in __init__(self, firefox_profile, firefox_binary, timeout, capabilities, proxy, executable_path, firefox_options, log_path)
#     141         if capabilities.get("marionette"):
#     142             capabilities.pop("marionette")
# --> 143             self.service = Service(executable_path, log_path=log_path)
#     144             self.service.start()
#     145
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/site-packages/selenium/webdriver/firefox/service.py in __init__(self, executable_path, port, service_args, log_path, env)
#      42
#      43         """
# ---> 44         log_file = open(log_path, "a+") if log_path is not None and log_path != "" else None
#      45
#      46         service.Service.__init__(
#
# OSError: [Errno 24] Too many open files: 'geckodriver.log'
# Gris fläsk kotlett fett bortskuret rå 982
# Found: 0 images
# image count 1
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/Development/kodamat/scrape-google-image-search.py in <module>()
#     125     print("image count", len(image_urls))
#     126
# --> 127     pool = Pool(12)
#     128     results = pool.map(persist_image, values)
#     129     print("Images downloaded: ", len([r for r in results if r]))
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/context.py in Pool(self, processes, initializer, initargs, maxtasksperchild)
#     116         from .pool import Pool
#     117         return Pool(processes, initializer, initargs, maxtasksperchild,
# --> 118                     context=self.get_context())
#     119
#     120     def RawValue(self, typecode_or_type, *args):
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/pool.py in __init__(self, processes, initializer, initargs, maxtasksperchild, context)
#     154                  maxtasksperchild=None, context=None):
#     155         self._ctx = context or get_context()
# --> 156         self._setup_queues()
#     157         self._taskqueue = queue.Queue()
#     158         self._cache = {}
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/pool.py in _setup_queues(self)
#     248     def _setup_queues(self):
#     249         self._inqueue = self._ctx.SimpleQueue()
# --> 250         self._outqueue = self._ctx.SimpleQueue()
#     251         self._quick_put = self._inqueue._writer.send
#     252         self._quick_get = self._outqueue._reader.recv
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/context.py in SimpleQueue(self)
#     109         '''Returns a queue object'''
#     110         from .queues import SimpleQueue
# --> 111         return SimpleQueue(ctx=self.get_context())
#     112
#     113     def Pool(self, processes=None, initializer=None, initargs=(),
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/queues.py in __init__(self, ctx)
#     313     def __init__(self, *, ctx):
#     314         self._reader, self._writer = connection.Pipe(duplex=False)
# --> 315         self._rlock = ctx.Lock()
#     316         self._poll = self._reader.poll
#     317         if sys.platform == 'win32':
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/context.py in Lock(self)
#      64         '''Returns a non-recursive lock object'''
#      65         from .synchronize import Lock
# ---> 66         return Lock(ctx=self.get_context())
#      67
#      68     def RLock(self):
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/synchronize.py in __init__(self, ctx)
#     161
#     162     def __init__(self, *, ctx):
# --> 163         SemLock.__init__(self, SEMAPHORE, 1, 1, ctx=ctx)
#     164
#     165     def __repr__(self):
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/synchronize.py in __init__(self, kind, value, maxvalue, ctx)
#      58                 sl = self._semlock = _multiprocessing.SemLock(
#      59                     kind, value, maxvalue, self._make_name(),
# ---> 60                     unlink_now)
#      61             except FileExistsError:
#      62                 pass
#
# OSError: [Errno 24] Too many open files
# Grillkorv fett 15% 1508
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/Development/kodamat/scrape-google-image-search.py in <module>()
#     119     ensure_directory(query_directory)
#     120
# --> 121     image_urls = fetch_image_urls(args.query, args.count)
#     122
#     123     values = [item for item in zip(itertools.cycle([query_directory]), image_urls)]
#
# ~/Development/kodamat/scrape-google-image-search.py in fetch_image_urls(query, images_to_download)
#      56
#      57     search_url = "https://www.google.com/search?safe=off&site=&tbm=isch&source=hp&q={q}&oq={q}&gs_l=img"
# ---> 58     browser = webdriver.Firefox()
#      59     browser.get(search_url.format(q=query))
#      60     #def scroll_to_bottom():
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/site-packages/selenium/webdriver/firefox/webdriver.py in __init__(self, firefox_profile, firefox_binary, timeout, capabilities, proxy, executable_path, firefox_options, log_path)
#     141         if capabilities.get("marionette"):
#     142             capabilities.pop("marionette")
# --> 143             self.service = Service(executable_path, log_path=log_path)
#     144             self.service.start()
#     145
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/site-packages/selenium/webdriver/firefox/service.py in __init__(self, executable_path, port, service_args, log_path, env)
#      42
#      43         """
# ---> 44         log_file = open(log_path, "a+") if log_path is not None and log_path != "" else None
#      45
#      46         service.Service.__init__(
#
# OSError: [Errno 24] Too many open files: 'geckodriver.log'
# Blomkål gratinerad 433
# Found: 0 images
# image count 1
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/Development/kodamat/scrape-google-image-search.py in <module>()
#     125     print("image count", len(image_urls))
#     126
# --> 127     pool = Pool(12)
#     128     results = pool.map(persist_image, values)
#     129     print("Images downloaded: ", len([r for r in results if r]))
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/context.py in Pool(self, processes, initializer, initargs, maxtasksperchild)
#     116         from .pool import Pool
#     117         return Pool(processes, initializer, initargs, maxtasksperchild,
# --> 118                     context=self.get_context())
#     119
#     120     def RawValue(self, typecode_or_type, *args):
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/pool.py in __init__(self, processes, initializer, initargs, maxtasksperchild, context)
#     154                  maxtasksperchild=None, context=None):
#     155         self._ctx = context or get_context()
# --> 156         self._setup_queues()
#     157         self._taskqueue = queue.Queue()
#     158         self._cache = {}
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/pool.py in _setup_queues(self)
#     248     def _setup_queues(self):
#     249         self._inqueue = self._ctx.SimpleQueue()
# --> 250         self._outqueue = self._ctx.SimpleQueue()
#     251         self._quick_put = self._inqueue._writer.send
#     252         self._quick_get = self._outqueue._reader.recv
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/context.py in SimpleQueue(self)
#     109         '''Returns a queue object'''
#     110         from .queues import SimpleQueue
# --> 111         return SimpleQueue(ctx=self.get_context())
#     112
#     113     def Pool(self, processes=None, initializer=None, initargs=(),
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/queues.py in __init__(self, ctx)
#     313     def __init__(self, *, ctx):
#     314         self._reader, self._writer = connection.Pipe(duplex=False)
# --> 315         self._rlock = ctx.Lock()
#     316         self._poll = self._reader.poll
#     317         if sys.platform == 'win32':
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/context.py in Lock(self)
#      64         '''Returns a non-recursive lock object'''
#      65         from .synchronize import Lock
# ---> 66         return Lock(ctx=self.get_context())
#      67
#      68     def RLock(self):
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/synchronize.py in __init__(self, ctx)
#     161
#     162     def __init__(self, *, ctx):
# --> 163         SemLock.__init__(self, SEMAPHORE, 1, 1, ctx=ctx)
#     164
#     165     def __repr__(self):
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/synchronize.py in __init__(self, kind, value, maxvalue, ctx)
#      58                 sl = self._semlock = _multiprocessing.SemLock(
#      59                     kind, value, maxvalue, self._make_name(),
# ---> 60                     unlink_now)
#      61             except FileExistsError:
#      62                 pass
#
# OSError: [Errno 24] Too many open files
# Saftsoppa 1747
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/Development/kodamat/scrape-google-image-search.py in <module>()
#     119     ensure_directory(query_directory)
#     120
# --> 121     image_urls = fetch_image_urls(args.query, args.count)
#     122
#     123     values = [item for item in zip(itertools.cycle([query_directory]), image_urls)]
#
# ~/Development/kodamat/scrape-google-image-search.py in fetch_image_urls(query, images_to_download)
#      56
#      57     search_url = "https://www.google.com/search?safe=off&site=&tbm=isch&source=hp&q={q}&oq={q}&gs_l=img"
# ---> 58     browser = webdriver.Firefox()
#      59     browser.get(search_url.format(q=query))
#      60     #def scroll_to_bottom():
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/site-packages/selenium/webdriver/firefox/webdriver.py in __init__(self, firefox_profile, firefox_binary, timeout, capabilities, proxy, executable_path, firefox_options, log_path)
#     141         if capabilities.get("marionette"):
#     142             capabilities.pop("marionette")
# --> 143             self.service = Service(executable_path, log_path=log_path)
#     144             self.service.start()
#     145
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/site-packages/selenium/webdriver/firefox/service.py in __init__(self, executable_path, port, service_args, log_path, env)
#      42
#      43         """
# ---> 44         log_file = open(log_path, "a+") if log_path is not None and log_path != "" else None
#      45
#      46         service.Service.__init__(
#
# OSError: [Errno 24] Too many open files: 'geckodriver.log'
# Lättmargarin fett 40% berikad typ Lätt & lagom 20
# Found: 0 images
# image count 1
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/Development/kodamat/scrape-google-image-search.py in <module>()
#     125     print("image count", len(image_urls))
#     126
# --> 127     pool = Pool(12)
#     128     results = pool.map(persist_image, values)
#     129     print("Images downloaded: ", len([r for r in results if r]))
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/context.py in Pool(self, processes, initializer, initargs, maxtasksperchild)
#     116         from .pool import Pool
#     117         return Pool(processes, initializer, initargs, maxtasksperchild,
# --> 118                     context=self.get_context())
#     119
#     120     def RawValue(self, typecode_or_type, *args):
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/pool.py in __init__(self, processes, initializer, initargs, maxtasksperchild, context)
#     154                  maxtasksperchild=None, context=None):
#     155         self._ctx = context or get_context()
# --> 156         self._setup_queues()
#     157         self._taskqueue = queue.Queue()
#     158         self._cache = {}
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/pool.py in _setup_queues(self)
#     248     def _setup_queues(self):
#     249         self._inqueue = self._ctx.SimpleQueue()
# --> 250         self._outqueue = self._ctx.SimpleQueue()
#     251         self._quick_put = self._inqueue._writer.send
#     252         self._quick_get = self._outqueue._reader.recv
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/context.py in SimpleQueue(self)
#     109         '''Returns a queue object'''
#     110         from .queues import SimpleQueue
# --> 111         return SimpleQueue(ctx=self.get_context())
#     112
#     113     def Pool(self, processes=None, initializer=None, initargs=(),
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/queues.py in __init__(self, ctx)
#     313     def __init__(self, *, ctx):
#     314         self._reader, self._writer = connection.Pipe(duplex=False)
# --> 315         self._rlock = ctx.Lock()
#     316         self._poll = self._reader.poll
#     317         if sys.platform == 'win32':
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/context.py in Lock(self)
#      64         '''Returns a non-recursive lock object'''
#      65         from .synchronize import Lock
# ---> 66         return Lock(ctx=self.get_context())
#      67
#      68     def RLock(self):
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/synchronize.py in __init__(self, ctx)
#     161
#     162     def __init__(self, *, ctx):
# --> 163         SemLock.__init__(self, SEMAPHORE, 1, 1, ctx=ctx)
#     164
#     165     def __repr__(self):
#
# ~/anaconda/envs/traffic_signs/lib/python3.5/multiprocessing/synchronize.py in __init__(self, kind, value, maxvalue, ctx)
#      58                 sl = self._semlock = _multiprocessing.SemLock(
#      59                     kind, value, maxvalue, self._make_name(),
# ---> 60                     unlink_now)
#      61             except FileExistsError:
#      62                 pass
#
# OSError: [Errno 24] Too many open files
