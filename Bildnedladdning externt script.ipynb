# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
import sqlite3
import numpy as np
import random
import time
import os

# %%
conn = sqlite3.connect('livs.db')  # Create db and establish connection
conn.row_factory = sqlite3.Row
curs = conn.cursor()
result = []
rows = curs.execute('select Livsmedelsnamn, Livsmedelsnummer from livs')
for row in rows:
        result.append(row)

rows = np.array(result)
#rows = rows[970:]
#samples = random.sample(range(0, 1999), 10) #Sista siffran är antalet som laddas ner
sampledFoodItems = []
#print (type(sampledFoodItems))

for index, items in enumerate(rows):
    sampledFoodItems.append(result[index])

sampledFoodItems = np.array(rows)
sampledFoodItems = sampledFoodItems[1602:,:] #Här börjar man efter ett antal livsmedel
numberOf=len(sampledFoodItems)
#print(numberOf)
print (sampledFoodItems)

conn.close()
# Out:
# 486
# [['Chokladbollar' '1888']
#  ['Måltidsersättning chokladsmak pulver Nutrilett Intensiv' '1891']
#  ['Socker' '1892']
#  ['Brun farin' '1893']
#  ['Ljus sirap' '1894']
#  ['Honung' '1896']
#  ['Druvsocker' '1897']
#  ['Fruktsocker' '1898']
#  ['Sorbitol m sackarin' '1899']
#  ['Svagdricka  vol. % 2,3' '1900']
#  ['Öl lättöl vol. % 2,3' '1901']
#  ['Öl pilsner vol. % 3,5' '1902']
#  ['Cider vol. % 1' '1903']
#  ['Vitt vin  vol. % 1' '1904']
#  ['Rödvin rosévin vol. % 1' '1905']
#  ['Öl starköl el exportöl vol. % 5,6' '1906']
#  ['Rödvin vol. % 12' '1907']
#  ['Vitt vin halvtorrt el halvsött vol. % 12,5' '1908']
#  ['Vitt vin el rhenvin  vol. % 10' '1909']
#  ['Vitt vin sött vol. % 13,5' '1910']
#  ['Vitt vin torrt vol. % 12' '1911']
#  ['Vinglögg vol. % 10' '1912']
#  ['Madeira vol. % 18' '1914']
#  ['Portvin vitt rött vol. % 20' '1915']
#  ['Sherry halvtorr vol. % 17' '1916']
#  ['Starkvinsglögg vol. % 16' '1917']
#  ['Brännvin renat el vodka vol. % 40' '1918']
#  ['Likör söt vol. % 24' '1919']
#  ['Likör Kaptenlöjtnant vol. % 38' '1920']
#  ['Konjak el brandy vol. % 40' '1921']
#  ['Punsch vol. % 26' '1922']
#  ['Rom vol. % 40' '1923']
#  ['Kryddat brännvin vol. % 40' '1924']
#  ['Gin vol. % 40' '1925']
#  ['Whisky vol. % 40' '1926']
#  ['Likör mindre söt vol. % 24' '1927']
#  ['Irish coffee' '1929']
#  ['Bovetemjöl ljust' '1930']
#  ['Havremust pulver berik' '1931']
#  ['Kornmjöl fullkorn' '1932']
#  ['Majsmjöl gult u groddar el polenta' '1933']
#  ['Rågmjöl fullkorn' '1934']
#  ['Grahamsmjöl fullkorn vete' '1935']
#  ['Vetediet berik' '1936']
#  ['Vetemjöl bagerivetemjöl berik' '1937']
#  ['Vetemjöl bagerivetemjöl' '1938']
#  ['Vetemjöl berik' '1939']
#  ['Grovt vetemjöl berik' '1940']
#  ['Vetemjöl' '1941']
#  ['Mjölblandning grov vete råg vitberik' '1942']
#  ['Mjölblandning rågsikt m vetemjöl vitberik' '1943']
#  ['Mjölblandning vete råg korn havre vitberik' '1944']
#  ['Majsstärkelse' '1945']
#  ['Potatismjöl el potatisgryn' '1946']
#  ['Samarinpulver' '1947']
#  ['Samarin drickf' '1948']
#  ['Sodavatten' '1949']
#  ['Vichyvatten' '1950']
#  ['Mineralvatten' '1951']
#  ['Mineralvatten m tillsatt kalium' '1952']
#  ['Kranvatten' '1953']
#  ['Snabbkaffe pulver' '1955']
#  ['Snabbkaffe drickf' '1956']
#  ['Kaffe bryggt' '1957']
#  ['Bryggt kaffe espresso drickf' '1958']
#  ['Snabbkaffe koffeinfritt drickf' '1959']
#  ['Tepulver' '1960']
#  ['Te bryggt' '1962']
#  ['Örtte drickf' '1963']
#  ['Nyponte m svarta vinbär drickf' '1964']
#  ['Ättiksprit ättiksyra 12 %' '1965']
#  ['Vinäger ättiksyra 7 %' '1966']
#  ['Äppelcidervinäger ättiksyra 7 %' '1967']
#  ['Chilisås tomat' '1968']
#  ['Ketchup' '1969']
#  ['HP-sås' '1970']
#  ['Grillsås' '1971']
#  ['Senap svensk' '1972']
#  ['Senap fransk' '1973']
#  ['Sötsur sås' '1974']
#  ['Joderat salt' '1975']
#  ['Mineralsalt' '1976']
#  ['Havssalt' '1977']
#  ['Örtsalt' '1978']
#  ['Färsk jäst' '1979']
#  ['Torrjäst' '1980']
#  ['Bakpulver' '1981']
#  ['Béchamelsås lättmjölk' '1982']
#  ['Ljus sås mjölk' '1983']
#  ['Ljus sås lättmjölk' '1984']
#  ['Béchamelsås' '1985']
#  ['Gratängsås' '1986']
#  ['Ljus sås' '1987']
#  ['Ostsås' '1988']
#  ['Ostsås ädelost' '1989']
#  ['Ostsås till moussaka' '1990']
#  ['Brunsås mjölk' '1991']
#  ['Sky' '1992']
#  ['Brunsås' '1993']
#  ['Brunsås buljong' '1994']
#  ['Currysås' '1995']
#  ['Brunsås kaffegrädde' '1996']
#  ['Korintsås' '1997']
#  ['Brunsås pulver tillagad m mjölk vatten' '1998']
#  ['Gräddsås pulver tillagad m mjölk vatten smör' '1999']
#  ['Tomatsås' '2000']
#  ['Dillsås' '2001']
#  ['Äggsås m persilja' '2002']
#  ['Pesto' '2003']
#  ['Pestosås m basilika pinjenötter cashewnötter' '2004']
#  ['Dippmix pulver olika smaker' '2006']
#  ['Sweet chilisås' '2007']
#  ['Pastasås m tomat Findus' '2008']
#  ['Pastasås olika märken' '2009']
#  ['Sweet&sour sås Uncle Ben' '2010']
#  ['Orientalisk sås Uncle Ben' '2011']
#  ['Teriyakisås' '2012']
#  ['Frukostflingor fullkorn müsli Plus' '2024']
#  ['Frukostflingor fullkorn müsli Bär' '2025']
#  [ 'Frukostflingor fullkorn frukt nötter kokosolja socker typ Start hasselnöt'
#   '2027']
#  ['Frukostflingor fullkorn frukt nötter kokosolja socker crunchy russin'
#   '2028']
#  ['Frukostflingor frukt nötter/kokos olja socker: ICA Crunchy naturell'
#   '2029']
#  ['Frukostflingor fullkorn frukt nötter kokos olja socker F-müsli tropical'
#   '2030']
#  [ 'Frukostflingor fullkorn frukt olja socker typ Signum früsli crisp jordgubb'
#   '2031']
#  ['Frukostflingor fullkorn flingblandning frukt olja familjemüsli' '2032']
#  ['Frukostflingor fullkorn frukt olja F-müsli banan' '2033']
#  ['Crab sticks Ullmo' '2035']
#  ['Matlagningsbas fett 15% typ Milda mat' '2036']
#  ['Milda Minimat 7% fett' '2037']
#  ['Milda Fraiche 24% fett' '2038']
#  ['Milda Visp 20% fett' '2039']
#  ['Milda kaffe 10% fett' '2040']
#  ['Milda Vaniljvisp 12% fett' '2041']
#  ['Creme Fraiche Blue Cheese  fett 15%' '2042']
#  ['Creme Fraiche fett 13% smaksatt' '2043']
#  ['Creme Fraiche fett 28% smaksatt' '2044']
#  ['Frukostost fett 13% Kavli berikad +ABCDE' '2045']
#  ['Mini Fraiche fett 5%' '2046']
#  ['Milko greve fett 13% smältost' '2047']
#  ['Fjällfil naturell fett 4,2%' '2048']
#  ['Fjällyoghurt fett 3,6 % , olika smaksättningar' '2049']
#  ['Fettfri majonnäs  fett < 0.5%' '2050']
#  ['Vit choklad' '2051']
#  ['Mörk choklad kakao >70 %' '2052']
#  ['Mörk choklad kakao <70%' '2053']
#  ['Mörk blockchoklad' '2054']
#  ['Mjölkchoklad ospec.' '2055']
#  ['Kebabkött djupfryst stekfärdigt' '2056']
#  ['Avorio ris okokt' '2057']
#  ['Rostad lök' '2058']
#  ['Glasspinne hallon o mjölk fett 5,5% typ SIA' '2059']
#  ['Glasspinne fett 10%' '2060']
#  ['FiberBar naturell All-Bran' '2061']
#  ['Knäckemacka vete olika fyllningar typ Wasa Sandwich' '2062']
#  ['Fullkornsmacka råg olika fyllningar typ Wasa sandwich' '2063']
#  ['Falafel kikärtskroketter frysta' '2064']
#  ['Pytt-i-panna vegetarisk' '2065']
#  ['Sojakorv' '2066']
#  ['Gourmetbullar vegetariska djupfrysta typ Hälsans kök' '2067']
#  ['Vegetarisk färs sojaprotein fryst' '2068']
#  ['Vegebitar, grytbitar av veteprotein' '2069']
#  ['Matlagningsbas m soja fett 17% Alpro soya Cuisine' '2070']
#  ['Müslibar fullkorn berikad typ Special K Bar Red fruit' '2071']
#  ['Müslibar berikad typ Special K Chocolate' '2072']
#  ['Jordnötssås' '2073']
#  ['Coleslaw kall sås' '2075']
#  ['Löksås med grädde' '2078']
#  ['Äggnudlar kokta m salt' '2079']
#  ['Nässelstuvning' '2080']
#  ['Kantarellstuvning' '2081']
#  ['Ratatouille' '2083']
#  ['Potatisgratäng matlagningsgrädde' '2085']
#  ['Sjömansbiff' '2092']
#  ['Kreolsk gryta' '2093']
#  ['Flygande Jakob Kyckling bacon jordnötter banan' '2096']
#  ['Prinskorv stekt' '2097']
#  ['Skinkröra' '2098']
#  ['Hamburgare blandfärs stekt' '2099']
#  ['Köttfärssås blandfärs' '2100']
#  ['Nötfärs fett 10% stekt' '2101']
#  ['Nöt fläsk kött stekt ospec.' '2103']
#  ['Carbonara sås' '2104']
#  ['Skagenröra' '2107']
#  ['Fisksoppa' '2108']
#  ['Havregrynsgröt fullkorn fiberhavregryn' '2123']
#  ['Havregrynsgröt kokt m mjölk' '2124']
#  ['Glasnudlar kokta m salt' '2125']
#  ['Majsvälling' '2127']
#  ['Gröt fullkorn ospec.' '2128']
#  ['Pannkaka sojadryck' '2133']
#  ['Paj skinka broccoli' '2134']
#  ['Kebabpizza hemlagad' '2138']
#  ['Ost- och skinksås' '2142']
#  ['Tzatziki' '2144']
#  ['Ris a la malta m lättmjölk mellangrädde fett 4%' '2147']
#  ['Rödkålssallad m äpple' '2160']
#  ['Champinjoner stekta u fett' '2161']
#  ['Palsternacka kokt' '2162']
#  ['Gratängsås med ost' '2163']
#  ['Fänkål kokt' '2164']
#  ['Kroppkakor' '2165']
#  ['Currysås Lätt Crème Fraiche' '2173']
#  ['Korv stroganoff mager' '2174']
#  ['Ostkaka fett 7%' '2184']
#  ['Rapsolja' '2189']
#  ['Matfettsblandning fett 75% berikad typ Bregott' '2190']
#  ['Lättmargarin fett 40% berikad typ Lätta' '2192']
#  ['Äggröra' '2197']
#  ['Ägg konventionellt kokt' '2205']
#  ['Aloe Vera Juice Syreberikad Hela Pharma AB' '2210']
#  ['Aloe Vera Juice Sasco' '2214']
#  ['Aloe Vera Juice med grönt te Naturapoteket' '2216']
#  ['Aloe Berry nectar Forever Living Products' '2217']
#  ['Aloe Vera naturell Forever Living Products' '2218']
#  ['Toscaglasyr' '2219']
#  ['Pasta glutenfri okokt' '2220']
#  ['Fusilli / lasagneplattor glutenfri okokt' '2221']
#  ['Pepparkakor glutenfria' '2222']
#  ['Digestivekex fullkorn glutenfria' '2223']
#  ['Chokladkakor glutenfria' '2224']
#  ['Glutenfritt hårt bröd fibrer ca 7,5% typ Grovknäcke' '2225']
#  ['Tagliatelle äggpasta glutenfritt okokt' '2226']
#  ['Pasta 100 % majs glutenfri okokt' '2227']
#  ['Bearnaisesås fett 8% Kelda' '2228']
#  ['Klassisk gräddsås fett 6% Kelda' '2229']
#  ['Ostsås fett 8% Kelda' '2230']
#  ['Bearnaise sås typ Spisa Rydbergs' '2231']
#  ['Rödvin sås fett 1,5% Spisa Rydbergs' '2232']
#  ['Kebabasås vit fett 30% Rydbergs' '2233']
#  ['Svamp sås fett 8,5% Spisa Rydbergs' '2234']
#  ['Café de Paris sås fett 39% Spisa Rydbergs' '2235']
#  ['Varmkorv fett 7% Må gott' '2236']
#  ['Prinskorv fett 8% Må gott' '2237']
#  ['Chorizo fett 9% Må gott' '2238']
#  ['Lättkorv fett 7% Må gott' '2239']
#  ['Salami fett 9% Må gott' '2240']
#  ['Kokt medwurst fett 7% Må gott' '2241']
#  ['Fruktyoghurt lättsockrad fett 0,2%' '2242']
#  ['Fruktyoghurt lättsockrad laktosreducerad fett 0,1%' '2243']
#  ['Frukostflingor fullkorn sockrad frön & russin 40%' '2244']
#  ['Frukostflingor fullkorn naturell' '2245']
#  ['After eight choklad mint' '2246']
#  ['Mozzarella ost fett 20 %' '2255']
#  ['Fruktdryck nypon' '2301']
#  ['Energidryck typ Red Bull berikad' '2302']
#  ['Lättmargarin fett 30% berikad typ Carlshamn LättLätt' '2399']
#  ['Flytande margarin fett 80% berikad typ Carlshamn gottgott' '2400']
#  ['Flytande margarin mjölkfri fett 80% berikad typ Carlshamn' '2401']
#  ['Bordsmargarin fett 60% berikad typ Carlshamn Runda Bords' '2402']
#  ['Bordsmargarin mjölkfri fett 70% berikad typ Carlshamn' '2403']
#  ['Hushållsmargarin mjölkfri fett 80% berikad typ Carlshamn' '2404']
#  ['Hushållsmargarin fett 80% berikad typ Carlshamn gottgott' '2405']
#  ['Lammrygg lammhals kokt' '2413']
#  ['Tilapia' '2468']
#  ['Flytande margarin fett 80% berikad typ Mjuka Milda' '2470']
#  ['Lättmargarin fett 39% berikad typ Milda' '2471']
#  ['Lättmargarin fett 28% berikad typ Mini Lätta' '2472']
#  ['Flytande margarin fett 82% typ Becel' '2474']
#  ['Basmatiris okokt' '2475']
#  ['Jasminris okokt' '2477']
#  ['Råris fullkorn långkornigt okokt' '2478']
#  ['Grötris 5-25 min koktid okokt' '2479']
#  ['Ris långkornigt okokt' '2481']
#  ['Ris långkornigt parboiled okokt' '2482']
#  ['Snabbris salt 1% okokt' '2483']
#  ['Snabbris okokt' '2484']
#  ['Grötris rundkornigt 1 timmes koktid okokt' '2485']
#  ['Lättmargarin yoghurt fett 28% berikad typ Lätta' '2488']
#  ['Lättmargarin fett 38% berikad Becel olive' '2489']
#  ['Bordsmargarin fett 70% berikad typ Becel Gold' '2490']
#  ['Köttfärs blandfärs nöt 70% gris 30% rå' '2492']
#  ['Köttfärs blandfärs nöt 50% gris 50% rå' '2499']
#  ['Kebab m bröd sallad sås' '2506']
#  ['Kebab special m pommes frites' '2507']
#  ['Korv mos ketchup senap bostongurka' '2508']
#  ['Korv bröd ketchup senap' '2509']
#  ['Hamburgare m bröd ost dubbel från gatukök restaurang' '2510']
#  ['Hamburgare m bröd 90 g från gatukök restaurang' '2511']
#  ['Hamburgare m bröd ost från gatukök restaurang' '2512']
#  ['Basmatiris kokt' '2513']
#  ['Jasminris kokt' '2514']
#  ['Ris långkornigt kokt m salt' '2515']
#  ['Ris långkornigt parboiled kokt' '2516']
#  ['Råris fullkorn långkornigt kokt m salt' '2517']
#  ['Snabbris salt 1% kokt' '2518']
#  ['Snabbris kokt' '2519']
#  ['Tagliatelle äggpasta glutenfritt kokt' '2520']
#  ['Pasta glutenfri kokt' '2521']
#  ['Pasta majs 100% glutenfri kokt' '2522']
#  ['Gröna ärter kokta' '2547']
#  ['Kalops älg' '2548']
#  ['Älghögrev' '2552']
#  ['Älgryggbiff tjur' '2555']
#  ['Tacoskal' '2557']
#  ['Romansallat' '2559']
#  ['Rucolasallat' '2561']
#  ['Inlagd sill m gräddfilssås' '3035']
#  ['Senapssill m sås' '3036']
#  ['Chilinötter' '3069']
#  ['Bulgur kokt' '3136']
#  ['Ren korv rå' '3141']
#  ['Lamm korv rå' '3213']
#  ['Älgfärs' '3323']
#  ['Älg ytterlår' '3324']
#  ['Linfröolja' '3433']
#  ['Inlagd sill' '3500']
#  ['Quinoa röd kokt m salt' '3518']
#  ['Bulgur fullkorn kokt u salt' '3564']
#  ['Sojadryck berikad' '3668']
#  ['Couscous fullkorn kokt m salt' '3752']
#  ['Pasta berikad kokt m salt typ Gammaldags idealmakaroner' '3753']
#  ['Pasta berikad kokt m salt typ Idealmakaroner' '3754']
#  ['Pasta berikad kokt m salt typ snabbmakaroner' '3755']
#  ['Pasta kokt m salt' '3756']
#  ['Vita bönor torkade kokta m salt' '3760']
#  ['Stora vita bönor konserv' '3761']
#  ['Kikärter torkade kokta m salt' '3762']
#  ['Dinkel' '3786']
#  ['Rågsiktsbröd fibrer ca 7%' '3790']
#  ['Bröd vitt fibrer ca 5% typ Jättefranska' '3791']
#  ['Vitt bröd fibrer ca 6% typ Äntligen mjukbröd' '3792']
#  ['Hårt bröd fullkorn råg fibrer ca 14% typ Rågi Wasa' '3793']
#  ['Rågbröd fullkorn fibrer ca 6% typ Lingongrova Skördeglädje Gott gräddat'
#   '3794']
#  ['Vitt bröd fibrer ca 5% typ Pågenlimpan Skogaholmslimpa' '3795']
#  ['Grahamsbröd fullkorn fibrer ca 13% typ Polarkraft extrem' '3796']
#  ['Rågbröd fullkorn fibrer ca 7% typ Kornelle Fullkorn plus' '3797']
#  ['Korvbröd grovt' '3798']
#  ['Kikärter konserv' '3815']
#  ['Kidneybönor röda bönor konserv' '3816']
#  ['Svarta bönor konserv' '3817']
#  ['Hamburgerbröd' '3818']
#  ['Vitt bröd mjölk fibrer ca 4% typ tekaka' '3819']
#  ['Bruna bönor rullpack' '3820']
#  ['Gröna linser torkade kokta m salt' '3821']
#  ['Röda linser torkade kokta m salt' '3822']
#  ['Röda linser konserv' '3823']
#  ['Gröna linser konserv' '3824']
#  ['Hamburgerbröd grovt' '3825']
#  ['Pasta berikad kokt m salt' '3826']
#  ['Pasta >50% fullkorn kokt m salt' '3828']
#  ['Ägg ekologiskt rått' '3840']
#  ['Äggula ekologisk' '3841']
#  ['Dinkel speltvete kokt' '3845']
#  ['Mâchesallat' '4052']
#  ['Hampfröolja' '4074']
#  ['Lättmargarin m omega 3 mjölkfri fett 40% berikad typ Carlshamn' '4085']
#  ['Lättmargarin m växtstanol 7,2% fett 32% berikad typ Benecol' '4086']
#  ['Lättmargarin laktosfri m växtstanol 7,2% fett 32% berikad typ Benecol'
#   '4087']
#  ['Hushållsmargarin mjölkfri fett 80% berikad typ Milda' '4095']
#  ['Lättmargarin fett 40% berikad typ VitaDor' '4104']
#  ['Lättmargarin fett 40% berikad typ Coop' '4105']
#  ['Lättmargarin fett 40% berikad typ Willys' '4106']
#  ['Bordsmargarin fett 60% berikad typ Euroshopper' '4107']
#  ['Hushållsmargarin fett 70% berikad typ X-tra' '4109']
#  ['Hushållsmargarin fett 80% berikad typ VitaDor' '4110']
#  ['Hushållsmargarin fett 80% berikad typ Hemköp' '4111']
#  ['Hushållsmargarin fett 80% berikad typ ICA' '4112']
#  ['Nudlar kokta m kryddor' '4117']
#  ['Palmolja' '4131']
#  ['Ägg ekologiskt stekt' '4134']
#  ['Ägg ekologiskt kokt' '4135']
#  ['Pangasiusmal' '4226']
#  ['Solist rå' '4385']
#  ['Swift rå' '4386']
#  ['Solist kokt m salt' '4415']
#  ['Swift kokt m salt' '4416']
#  ['Asterix rå' '4445']
#  ['Risnudlar' '4447']
#  ['Risnudlar kokta' '4448']
#  ['Havtorn' '4456']
#  ['Potatis rå' '4457']
#  ['Potatis kokt m salt' '4458']
#  ['Grönkålssallad' '4504']
#  ['Kålrotslåda' '4505']
#  ['Färskpotatis kokt m salt' '4511']
#  ['Färskpotatis rå' '4512']
#  ['Inova rå' '4513']
#  ['King Edward rå' '4514']
#  ['Mandelpotatis rå' '4515']
#  ['Storkökspotatis kokt m salt' '4516']
#  ['Asterix kokt m salt' '4518']
#  ['Inova kokt m salt' '4519']
#  ['King Edward kokt m salt' '4520']
#  ['Mandelpotatis kokt m salt' '4521']
#  ['Gris fläskfärs fett 15% rå' '4583']
#  ['Hoki' '4586']
#  ['Aronia' '4588']
#  ['Vita vinbär' '4589']
#  ['Ris rundkornigt kokt m salt' '4591']
#  ['Pilgrimsmusslor' '4600']
#  ['Laxbullar m sås tillagade' '4601']
#  ['Fiskpinnar ugnsstekt' '4602']
#  ['Skarpsill' '4607']
#  ['Inlagd sill u lag' '4608']
#  ['Inlagd höstsill u lag' '4609']
#  ['Senapssill u sås' '4610']
#  ['Kapkummel' '4611']
#  ['Guldsparid' '4612']
#  ['Havsabborre' '4613']
#  ['Alaska pollock' '4615']
#  ['Guldsparid grillad' '4616']
#  ['Havsabborre grillad' '4617']
#  ['Olivolja extra jungfruolja' '4659']
#  ['Rapsolja kallpressad' '4661']
#  ['Flytande matfettsblandning fett 80 % typ smör och rapsolja' '4662']
#  ['Matfettsblandning fett 43% typ Bregott mindre' '4663']
#  ['Småtomater röda typ körsbärstomat' '4937']
#  ['Torkade tomater' '4938']
#  ['Broccoli kokt' '4939']
#  ['Spenat färsk' '4941']
#  ['Röd mangold småbladig färsk' '4942']
#  ['Kruksallat' '4946']
#  ['Lök röd' '4947']
#  ['Kantarell rå' '5007']
#  ['Hjort kött kronhjort rå' '5043']
#  ['Hjort färs dovhjort rå' '5044']
#  ['Ren kött kallrökt rå' '5045']
#  ['Hjort skav rå' '5046']
#  ['Hjort korv rå' '5047']
#  ['Vildsvin bog rå' '5048']
#  ['Vildsvin filé rå' '5049']
#  ['Rådjur stek rå' '5050']
#  ['Vildsvin stek rå' '5058']
#  ['Kyckling korv rå' '5059']
#  ['Vildsvin kött rå' '5060']
#  ['Bacon gris rökt stekt' '5062']
#  ['Rådjur bog rå' '5064']
#  ['Ren kött rå' '5065']
#  ['Nöt kött rå' '5066']
#  ['Lamm kött rå' '5067']
#  ['Lamm grytbitar rå' '5068']
#  ['Bordsmargarin fett 80 % berikad typ Flora original' '5085']
#  ['Bordsmargarin fett 59 % berikad typ Flora mellan' '5086']
#  ['Flytande matfettsblandning fett 80 % berikad typ raps- och smörolja Ica'
#   '5087']
#  ['Höstpotatis kokt u salt' '5136']
#  ['Julmust påskmust' '5147']
#  ['Slush drickf' '5149']
#  ['Mandeldryck berikad' '5150']
#  ['Alkoläsk kolsyrad dryck vol. % 4-5' '5152']
#  ['Potatis kokt u salt' '5153']
#  ['Tranbärsdryck drickf' '5184']
#  ['Barngröt hirs äpple päron fr 6 mån typ Holle' '5186']
#  ['Barngröt flerkorn äpple päron berik fr 12 mån typ Semper' '5188']
#  ['Barngröt fullkorn frukt bär berik fr 8 mån typ Semper' '5189']
#  ['Barngröt frukt äpple banan berik fr 6 mån typ Semper' '5190']
#  ['Barngröt mjölkfri berik typ Sinlac' '5191']
#  ['Barngröt fullkorn exotiska frukter müsli berik fr 12 mån typ Nestlé'
#   '5192']
#  ['Barngröt frukt päron banan berik fr 8 mån typ Nestlé' '5193']
#  ['Barngröt havre m banan mango berik fr 8 mån typ Nestlé' '5194']
#  ['Barngröt havre berik fr 6 mån typ God natt' '5195']
#  ['Barngröt havre m banan och hallon berik fr 6 mån typ Nestlé' '5196']
#  ['Fläsk kött rå' '5447']
#  ['Fläsk grytbitar rå' '5449']
#  ['Minimjölk fett < 0,1% berik D vitamin' '5727']
#  ['Örtagårdssås gräddfil' '5753']
#  ['Bolognese sås' '5756']
#  ['Aioli' '5758']
#  ['Guacamole' '5759']
#  ['Mandeldryck' '5828']
#  ['Tropisk juice drickf' '5859']
#  ['Sojabönor färska förvällda' '5860']
#  ['Sparris grön kokt' '5861']
#  ['Kålrot kokt' '5862']
#  ['Brysselkål kokt' '5863']
#  ['Rotselleri kokt' '5864']
#  ['Gula ärter kokta' '5865']
#  ['Bruna bönor kokta' '5866']
#  ['Gråärter kokta' '5867']
#  ['Åkerböna kokt' '5868']
#  ['Äpple rött typ röd aroma' '5869']
#  ['Äpple rött typ Ingrid Marie' '5870']
#  ['Äpple typ Frida' '5871']
#  ['Äpple grönt typ Golden delicious Granny Smith' '5872']
#  ['Tacosås' '5916']
#  ['Hälleflundra odlad Atlanten rå' '5926']
#  ['Korngryn kokt u salt' '5935']
#  ['Torsk odlad rå' '5936']
#  ['Julmust light' '5942']
#  ['Havregurt naturell berikad' '5956']
#  ['Matlagningsbas m havre fett 15% typ Oatly fraiche' '5957']
#  ['Havrebaserat pålägg typ påmackan' '5961']
#  ['Havregurt smaksatt bägare berikad' '5962']
#  ['Fullkornsdryck havre typ Oatly' '5963']
#  ['Havredryck oberikad' '5964']
#  ['Kryddblandning taco' '5973']
#  ['Tortilla wrap' '5974']]

# %%
#Ca 5 sekunder för varje nedladdning, ca 3 timmar för hela db?

for keyword in sampledFoodItems:
    #print (keyword[0], keyword[1])
    name="'" + keyword[0] + "'"
    number=keyword[1]
    # %run scrape-google-image-search.py $name --label $number --count 4
# Out:
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/Development/kodamat/scrape-google-image-search.py in <module>()
#     119     image = Image.open(image_file).convert('RGB')
#     120     #resized = image.resize(size)
# --> 121     with open(query_directory + args.label + '_' + args.query + ".jpg", 'wb')  as f:
#     122         image.save(f, "JPEG", quality=85)
#     123
#
# FileNotFoundError: [Errno 2] No such file or directory: './images/2029_Frukostflingor frukt nötter/kokos olja socker: ICA Crunchy naturell.jpg'
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/Development/kodamat/scrape-google-image-search.py in <module>()
#     119     image = Image.open(image_file).convert('RGB')
#     120     #resized = image.resize(size)
# --> 121     with open(query_directory + args.label + '_' + args.query + ".jpg", 'wb')  as f:
#     122         image.save(f, "JPEG", quality=85)
#     123
#
# FileNotFoundError: [Errno 2] No such file or directory: './images/2221_Fusilli / lasagneplattor glutenfri okokt.jpg'
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
# Found: 0 images
