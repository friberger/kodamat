# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
pd_data = pd.read_csv('LivsmedelsDB_201809111439.csv', delimiter = ';')

# %%
pd_data
# Out:
#                                          Livsmedelsnamn  Livsmedelsnummer  \
# 0                                              Talg nöt                 1
# 1                                            Späck gris                 2
# 2                                            Ister gris                 3
# 3                                             Kokosfett                 4
# 4     Matfettsblandning havssaltat fett 80% berikad ...                 5
# 5     Matfettsblandning fett 60 % berikad typ Bregot...                 6
# 6              Bordsmargarin fett 70% berikad typ Milda                 7
# 7     Bordsmargarin extrasaltat fett 60% berikad typ...                 8
# 8     Bordsmargarin mjölkfri fett 60% berikad typ Milda                 9
# 9     Flytande margarin fett 82 % berikad typ Milda ...                10
# 10          Hushållsmargarin fett 80% berikad typ Melba                12
# 11          Hushållsmargarin fett 80% berikad typ Milda                13
# ...

# %%
def search(namn):
    nummer = pd_data['Livsmedelsnamn'].str.contains(namn)
    return nummer

pd_data[search('nöt')]
# Out:
#                                          Livsmedelsnamn  Livsmedelsnummer  \
# 0                                              Talg nöt                 1
# 615   Frukostflingor flingblandning müsli fullkorn f...               721
# 872                                   Oxrulad nöt stekt              1043
# 884   Dillkött m nötkött m purjolök morötter o sås h...              1060
# 885            Kalops nötkött lök morötter sås hemlagad              1061
# 886                             Biff Stroganoff nötkött              1062
# 891                                     Gulasch nötkött              1068
# 893                                   Köttsoppa nötkött              1073
# 895             Pepparrotskött nötkött lök morötter sås              1078
# 900                       Biff Stroganoff nötkött fryst              1087
# 901                        Dillkött nötkött m sås fryst              1088
# 906                            Kalops nötkött fryst sås              1095
# ...

# %%
pd_data.corr()
# Out:
#                      Livsmedelsnummer  Energi (kcal)  Energi (kJ)  \
# Livsmedelsnummer             1.000000       0.024879     0.024889
# Energi (kcal)                0.024879       1.000000     0.999998
# Energi (kJ)                  0.024889       0.999998     1.000000
# Fullkorn totalt (g)         -0.039825       0.158459     0.158432
# β-Karoten (µg)              -0.059396      -0.082545    -0.082491
#
#                      Fullkorn totalt (g)  β-Karoten (µg)
# Livsmedelsnummer               -0.039825       -0.059396
# Energi (kcal)                   0.158459       -0.082545
# Energi (kJ)                     0.158432       -0.082491
# Fullkorn totalt (g)             1.000000       -0.043971
# β-Karoten (µg)                 -0.043971        1.000000
