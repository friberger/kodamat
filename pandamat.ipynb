# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
pd_data = pd.read_csv('LivsmedelsDB_201611160847_01.csv', delimiter = ',')

# %%
pd_data
# Out:
#                                          Livsmedelsnamn  Livsmedelsnummer  \
# 0                                              Talg nöt                 1
# 1                                            Späck gris                 2
# 2                                            Ister gris                 3
# 3                                             Kokosfett                 4
# 4     Matfettsblandning havssaltat fett 80% berikad ...                 5
# ...                                                 ...               ...
# 2083                  Havregurt smaksatt bägare berikad              5962
# 2084                     Fullkornsdryck havre typ Oatly              5963
# 2085                                Havredryck oberikad              5964
# 2086                                Kryddblandning taco              5973
# 2087                                      Tortilla wrap              5974
#
#       Energi (kcal)  Energi (kJ)  Kolhydrater (g)  Fett (g)  Protein (g)  \
# ...

# %%
def search(namn):
    nummer = pd_data['Livsmedelsnamn'].str.contains(namn)
    return nummer

pd_data[search('nöt')]
# Out:
#                                          Livsmedelsnamn  Livsmedelsnummer  \
# 0                                              Talg nöt                 1
# 616   Frukostflingor flingblandning müsli fullkorn f...               721
# 875                                   Oxrulad nöt stekt              1043
# 886   Dillkött m nötkött m purjolök morötter o sås h...              1060
# 887            Kalops nötkött lök morötter sås hemlagad              1061
# 888                             Biff Stroganoff nötkött              1062
# 893                                     Gulasch nötkött              1068
# 895                                   Köttsoppa nötkött              1073
# 897             Pepparrotskött nötkött lök morötter sås              1078
# 902                       Biff Stroganoff nötkött fryst              1087
# 903                        Dillkött nötkött m sås fryst              1088
# 908                            Kalops nötkött fryst sås              1095
# ...

# %%
pd_data.corr()
# Out:
#                                    Livsmedelsnummer  Energi (kcal)  \
# Livsmedelsnummer                           1.000000       0.031493
# Energi (kcal)                              0.031493       1.000000
# Energi (kJ)                                0.031500       1.000000
# Kolhydrater (g)                            0.016047       0.451475
# Fett (g)                                   0.029485       0.813391
# Protein (g)                               -0.027877       0.113583
# Fibrer (g)                                -0.036281       0.190853
# Vatten (g)                                -0.017441      -0.881793
# Alkohol (g)                                0.037845      -0.003524
# Aska (g)                                  -0.013165       0.009753
# Monosackarider (g)                        -0.008420       0.028893
# Disackarider (g)                           0.025397       0.301711
# Sackaros (g)                               0.043829       0.283853
# ...
